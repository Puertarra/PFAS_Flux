# %%
import pickle
import numpy as np
import pandas as pd

# %%
pickle_path = "../data/plume_xsec_records.pkl"

# %%
with open(pickle_path, 'rb') as f:
    data = pickle.load(f)

# %%
data = data.sort_values(by=['Landfill', 'Type', 'Date']).reset_index(drop=True) 
data
# Out:
#    Landfill        Date                   Type  Wind_Direction_deg  \
# 0      LF19  2021-08-18   Area_Source_Modeling               180.0
# 1      LF19  2021-08-18   Area_Source_Modeling               180.0
# 2      LF19  2021-08-18   Area_Source_Modeling               180.0
# 3      LF19  2021-08-18   Area_Source_Modeling               180.0
# 4      LF19  2022-03-30   Area_Source_Modeling               110.0
# 5      LF19  2022-03-30   Area_Source_Modeling               110.0
# 6      LF19  2022-03-30   Area_Source_Modeling               110.0
# 7      LF19  2022-03-30   Area_Source_Modeling               110.0
# 8      LF19  2022-04-28   Area_Source_Modeling                10.0
# 9      LF19  2022-04-28   Area_Source_Modeling                10.0
# 10     LF19  2022-04-28   Area_Source_Modeling                10.0
# 11     LF19  2022-04-28   Area_Source_Modeling                10.0
# 12     LF19  2021-08-18  Point_Source_Modeling               180.0
# ...

# %%
with open(pickle_path, 'wb') as f:
    pickle.dump(data, f)
